# %%
from langchain_community.document_loaders import TextLoader
loader = TextLoader("speech.txt")
# Out:
# f:\AI\AI\Day_1\venv\Lib\site-packages\langchain_core\_api\deprecation.py:25: UserWarning: Core Pydantic V1 functionality isn't compatible with Python 3.14 or greater.
#   from pydantic.v1.fields import FieldInfo as FieldInfoV1

# %%
text=loader.load()

# %%
text
# Out:
# [Document(metadata={'source': 'speech.txt'}, page_content='Empowering Youth: Kalam often encouraged young people to be unique in a world trying to make them like everyone else, urging them to become leaders in their fields.\nOvercoming Failure: In his famous 1979 SLV-3 failure anecdote, he taught that failures are "First Attempts In Learning" (FAIL) and that one must persevere to succeed.\nVision for India: He emphasized making India a strong, self-reliant, developed nation through technology, agriculture, and education.\nCharacter and Education: He believed that education should foster creativity, righteousness in the heart, and character, which leads to harmony in the home and society.')]

# %%
from langchain_community.document_loaders import PyPDFLoader
load_pdf=PyPDFLoader('Shubham.pdf')
pdf=load_pdf.load()
pdf
# Out:
# [Document(metadata={'producer': 'Microsoft: Print To PDF', 'creator': 'PyPDF', 'creationdate': '2026-03-06T20:52:00+05:30', 'author': '', 'moddate': '2026-03-06T20:52:00+05:30', 'title': 'Shubham Kumar Resume 4+ exp.docx', 'source': 'Shubham.pdf', 'total_pages': 1, 'page': 0, 'page_label': '1'}, page_content="Shubham Kumar.Net Developer (4+ Year)Experienced .NET Developer with over 4+ years of expertise in designing and developingscalable web applications and backend batch jobs using ASP .NET Core, C#, Web API, and SQLServer. Proficient in building RESTful APIs, implementing automation solutions. Skilled inoptimizing SQL performance and delivering cloud-native solutions on Microsoft Azure.Recognized for strong analytical capabilities, collaborative teamwork, and a commitment tocontinuous learning and applying industry best practices. Seeking to contribute toinnovative software development initiatives that drive business impact and operationalexcellence.I'm looking for a job where I c
# ...

# %% [markdown]
# #Text Splitter

# %%
from langchain_text_splitters import RecursiveCharacterTextSplitter
text_splitter=RecursiveCharacterTextSplitter(chunk_size=100,chunk_overlap=20)
Final_Document = text_splitter.split_documents(pdf)
Final_Document 
# Final_Documentx=Final_Document[0].page_content
# Final_Documentx
# Out:
# [Document(metadata={'producer': 'Microsoft: Print To PDF', 'creator': 'PyPDF', 'creationdate': '2026-03-06T20:52:00+05:30', 'author': '', 'moddate': '2026-03-06T20:52:00+05:30', 'title': 'Shubham Kumar Resume 4+ exp.docx', 'source': 'Shubham.pdf', 'total_pages': 1, 'page': 0, 'page_label': '1'}, page_content='Shubham Kumar.Net Developer (4+ Year)Experienced .NET Developer with over 4+ years of expertise in'),
#  Document(metadata={'producer': 'Microsoft: Print To PDF', 'creator': 'PyPDF', 'creationdate': '2026-03-06T20:52:00+05:30', 'author': '', 'moddate': '2026-03-06T20:52:00+05:30', 'title': 'Shubham Kumar Resume 4+ exp.docx', 'source': 'Shubham.pdf', 'total_pages': 1, 'page': 0, 'page_label': '1'}, page_content='of expertise in designing and developingscalable web applications and backend batch jobs using ASP'),
# ...

# %%
speech=""
with open("speech.txt") as f:
    speech=f.read()
    # print(sppech)
text_splitter=RecursiveCharacterTextSplitter(chunk_size=100 ,chunk_overlap=20)
text=text_splitter.create_documents([speech])
print(text)
# Out:
# [Document(metadata={}, page_content='Empowering Youth: Kalam often encouraged young people to be unique in a world trying to make them'), Document(metadata={}, page_content='trying to make them like everyone else, urging them to become leaders in their fields.'), Document(metadata={}, page_content='Overcoming Failure: In his famous 1979 SLV-3 failure anecdote, he taught that failures are "First'), Document(metadata={}, page_content='failures are "First Attempts In Learning" (FAIL) and that one must persevere to succeed.'), Document(metadata={}, page_content='Vision for India: He emphasized making India a strong, self-reliant, developed nation through'), Document(metadata={}, page_content='nation through technology, agriculture, and education.'), Document(metadata={}, page_content='Character and Education: He believed that education should foster creativity, righteousness in the'), Document(metadata={}, page_content='in the heart, and character, which leads to harmony in the home and 
# ...

# %%
from langchain_community.document_loaders import TextLoader
loader=TextLoader('speech.txt')
doc=loader.load()
doc

# %%
from langchain_text_splitters import CharacterTextSplitter
text_splitte=CharacterTextSplitter(separator="\n\n",chunk_size=100 ,chunk_overlap=20)
x=text_splitte.split_documents(doc)
x
